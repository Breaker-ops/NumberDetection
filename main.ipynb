# %%
import os
import cv2
from PIL import Image
import numpy as np

# %%
os.listdir("data/1")
# Out:
# ['IMG_20260205_114815.jpg',
#  'IMG_20260205_114934.jpg',
#  'IMG_20260205_11555.jpg',
#  'IMG_20260205_115039.jpg',
#  'IMG_20260205_11570.jpg',
#  'IMG_20260205_1150398.jpg',
#  'IMG_20260205_115709.jpg',
#  'IMG_20260205_1555.jpg',
#  'IMG_20260205_11579.jpg',
#  'IMG_20260205_114857.jpg',
#  'IMG_20260205_115023.jpg',
#  'IMG_20260205_11505.jpg',
#  'IMG20260205_11579.jpg',
#  'IMG_20260205_114624.jpg',
#  'IMG_20260205_11558.jpg',
#  'IMG_20260205_114949.jpg',
#  'IMG_20260205_114841.jpg',
#  'IMG_20260205_115006.jpg',
#  'IMG_20260205_115058.jpg',
#  'IMG_20260205_15555.jpg',
#  'IMG_20260205_115555.jpg',
#  'IMG_20260205_115719.jpg']

# %%
DATA_DIR = "DATASET"

# %%
os.listdir("/home/franc-stile/Bureau/KNN/data/")
# Out:
# ['7', '6', '8', '4', '2', '5', '9', '3', '1']

# %%
for label in os.listdir("/home/franc-stile/Bureau/KNN/data/") :
    label_path = os.path.join("/home/franc-stile/Bureau/KNN/data/", label)
    if os.path.isdir(label_path) :
        output_label = os.path.join(DATA_DIR, label)
        os.makedirs(output_label, exist_ok=True)

        for file in os.listdir(label_path) :
            image_path = os.path.join(label_path, file)
            try :
                img = Image.open(image_path)
                img_resized = img.resize((600, 600))
                save_path = os.path.join(output_label, file)
                img_resized.save(save_path)
            except :
                print("Erreur avec :", image_path)
print("Toutes les images ont été redimensionnées")
# Out:
# Toutes les images ont été redimensionnées

# %%
class KNN:
    def __init__(self, k=3):
        self.k = k

    def fit(self, X, y):
        self.X_train = X
        self.y_train = y

    def _euclidean_distance(self, x1, x2):
        return np.sqrt(np.sum((x1 - x2) ** 2))

    def predict(self, X):
        predictions = [self._predict(x) for x in X]
        return np.array(predictions)

    def _predict(self, x):
        # calcul des distances
        distances = [self._euclidean_distance(x, x_train) for x_train in self.X_train]

        # indices des k plus proches
        k_indices = np.argsort(distances)[:self.k]

        # labels des voisins
        k_nearest_labels = [self.y_train[i] for i in k_indices]

        # vote majoritaire
        values, counts = np.unique(k_nearest_labels, return_counts=True)
        return values[np.argmax(counts)]

# %%
path_dir = os.path.join("./", DATA_DIR)

# %%
directory = os.listdir(path_dir)
directory.sort()

# %%
os.listdir("DATASET/1/")

# %%
data = []
labels = []

# %%
i = 1
for dirs in directory :
    listfile = []
    for file in os.listdir(os.path.join(DATA_DIR, dirs)) :
        img = cv2.imread(os.path.join(DATA_DIR, dirs, file))
        img = np.array(img).flatten()
        listfile.append(img)
    data.append(listfile)
    labels.append(dirs)

# %%
labels = np.array(labels)

# %%
data[0][0].shape
# Out:
# (2352,)

# %%
knn = KNN(k=3)

# %%
knn.fit(data, labels)

# %%
x_test = data[0][0]

# %%
x_test
# Out:
# array([177, 173, 179, ..., 175, 167, 178], dtype=uint8)

# %%
i = 0
for x in x_test :
    print(x)
    if i == 8 :
        break
    i += 1
# Out:
# 177
# 173
# 179
# 177
# 173
# 179
# 177
# 173
# 179
